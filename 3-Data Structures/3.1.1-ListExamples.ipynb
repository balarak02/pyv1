# %% [markdown]
# #### Real-World Examples Using Lists in Python
# Lists are one of the most commonly used data structures in Python, thanks to their versatility and ease of use. Here are several practical examples that illustrate their use in real-world scenarios

# %% [markdown]
# ##### Example 1. Manage A To Do List
# - Create a To Do List To Keep Track OF Tasks

# %%
'''to_do_list=["Buy Groceries","Clean the house","Pay bills"]

## Adding to task
to_do_list.append("Schedule meeting")
to_do_list.append("Go For a Run")

## Removing a completed task
to_do_list.remove("Clean the house")

## checking if a task is in the list
if "Pay bills" in to_do_list:
    print("Don't forgrt to pay the utility bills")

print("To Do List remaining")
for task in to_do_list:
    print(f"-{task}")'''

todo=["Finish Pipeline","Prepare for PPT","Draft mail to Leasing Office"]
todo.append("Update Documentation")
todo.append("Check the SF ")

recent=todo.pop()
print("The recently completed task is: ",recent)
if "Draft mail to Leasing Office" in todo:
    print("Draft the mail to leasing office \n")
print("Remaining Tasks: ",todo)
# Out:
# The recently completed task is:  Check the SF
# Draft the mail to leasing office
#
# Remaining Tasks:  ['Finish Pipeline', 'Prepare for PPT', 'Draft mail to Leasing Office', 'Update Documentation']

# %% [markdown]
# ##### Example 2: Organizing Student Grades
# - Create a list to store and calculate average grades for students

# %%
'''# Organizing student grades
grades = [85, 92, 78, 90, 88]

# Adding a new grade
grades.append(95)

# Calculating the average grade
average_grade = sum(grades) / len(grades)
print(f"Average Grade: {average_grade:.2f}")

# Finding the highest and lowest grades
highest_grade = max(grades)
lowest_grade = min(grades)
print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")'''

gr=[104,956,863,946,745,632]
gr.append(1000)
#Print Avg.
listsum=sum(gr)
listlen=len(gr)
avg=listsum/listlen
print("The avg is: ",avg)
gr.sort()
print("The asc is: ",gr)
gr.sort(reverse=True)
print("The desc is: ",gr)
print(gr)
print("the highest is: ",gr[-1])
# Out:
# The avg is:  749.4285714285714
# The asc is:  [104, 632, 745, 863, 946, 956, 1000]
# The desc is:  [1000, 956, 946, 863, 745, 632, 104]
# [1000, 956, 946, 863, 745, 632, 104]
# the highest is:  104

# %% [markdown]
# ##### Example 3: Managing An Inventory
# - Use a list to manage inventory items in a store

# %%
''''# Managing an inventory
inventory = ["apples", "bananas", "oranges", "grapes", "bananas"]

# Adding a new item
inventory.append("strawberries")

# Removing an item that is out of stock
inventory.remove("bananas")

print("the inventory is:", inventory)


# Checking if an item is in stock
item = "oranges"
if item in inventory:
    print(f"{item} are in stock.")
else:
    print(f"{item} are out of stock.")

# Printing the inventory
print("Inventory List:")
for item in inventory:
    print(f"- {item}")'''


inventory=[]
for i in range(int(input("enter the number of items to add: "+1))):
    inventory.append(str(input("Enter the item name to add: (Avoid Duplicates)" )))

print("the inventory is: ",inventory)

for i in range(int(input("Enter the nuumber of items to remove: "+1))):
            inventory.remove(str(input("Enter the item to remove: ")))

print("The updated inventory is: ",inventory)

if str(input("Enter the item to check: ")) in inventory:
        print("Item is in stock: ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 28
#      26 inventory=[]
#      27 no=int(input("Enter the number of items to add to inventory: "))
# ---> 28 for i in range(int(input("enter the number of items to add: "+1))):
#      29     inventory.append(str(input("Enter the item name to add: (Avoid Duplicates)" )))
#      31 print("the inventory is: ",inventory)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ##### Example 4:Collecting User Feedback
# - Use a list to collect and analyze user feedback.

# %%
# Collecting user feedback
feedback = ["Great service!", "Very satisfied", "Could be better", "Excellent experience"]

# Adding new feedback
feedback.append("Not happy with the service")

# Counting specific feedback
positive_feedback_count = sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())
print(f"Positive Feedback Count: {positive_feedback_count}")

# Printing all feedback
print("User Feedback:")
for comment in feedback:
    print(f"- {comment}")
# Out:
# Positive Feedback Count: 2
# User Feedback:
# - Great service!
# - Very satisfied
# - Could be better
# - Excellent experience
# - Not happy with the service
